# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("moves_to_pokemon.csv", index_col="id")
df.head()
# Out:
#     pokemon_id    method  move_id
# id
# 0            1   Level 0      492
# 1            1   Level 3      195
# 2            1   Level 7      264
# 3            1   Level 9      529
# 4            1  Level 13      339

# %%
df1 = pd.read_csv("pokemon_moves.csv", index_col="id")
df1.head()
# Out:
#                                                   url   move_name move_type  \
# id
# 0   https://www.serebii.net/attackdex-bw/absorb.shtml      Absorb     grass
# 1     https://www.serebii.net/attackdex-bw/acid.shtml        Acid    poison
# 2   https://www.serebii.net/attackdex-bw/acidarmor...  Acid Armor    poison
# 3   https://www.serebii.net/attackdex-bw/acidspray...  Acid Spray    poison
# 4   https://www.serebii.net/attackdex-bw/acrobatic...  Acrobatics    flying
#
#    move_category  move_pp  move_power  move_accuracy  \
# id
# 0        special       25          20            100
# 1        special       30          40            100
# 2          other       40           0              0
# 3        special       20          40            100
# 4       physical       15          55            100
#
#                                      move_description  \
# id
# 0   A nutrient-draining attack. The user's HP is r...
# 1   The opposing team is attacked with a spray of ...
# ...

# %%
df2 = pd.read_csv("pokemon_species.csv", index_col="id")
df2.head()
# Out:
#                                              url        name  type1   type2  \
# id
# 0   https://www.serebii.net/pokedex-bw/001.shtml   Bulbasaur  grass  poison
# 1   https://www.serebii.net/pokedex-bw/002.shtml     Ivysaur  grass  poison
# 2   https://www.serebii.net/pokedex-bw/003.shtml    Venusaur  grass  poison
# 3   https://www.serebii.net/pokedex-bw/004.shtml  Charmander   fire     NaN
# 4   https://www.serebii.net/pokedex-bw/005.shtml  Charmeleon   fire     NaN
#
#     ability1 ability2 hidden_ability  HP  Atk  Def  SpA  SpD  Spe  total
# id
# 0   Overgrow      NaN    Chlorophyll  45   49   49   65   65   45    318
# 1   Overgrow      NaN    Chlorophyll  60   62   63   80   80   60    405
# 2   Overgrow      NaN    Chlorophyll  80   82   83  100  100   80    525
# 3      Blaze      NaN    Solar Power  39   52   43   60   50   65    309
# 4      Blaze      NaN    Solar Power  58   64   58   80   65   80    405
